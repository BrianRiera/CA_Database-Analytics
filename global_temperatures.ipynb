# %%
import json
import pandas as pd
import pymongo
from sqlalchemy import create_engine
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open('Global_Temperatures.json', 'r') as file:
    global_temperature = json.load(file)
    
client = pymongo.MongoClient('192.168.56.30', 27017)
db = client.climate
collection = db.global_temperature_collection

for document in global_temperature:
    collection.insert_one(document)

# %%
#Extract data from Mongodb
cursor = collection.find()
data = list(cursor)
# Convert data to a pandas DataFrame for temperature
temperature_df = pd.DataFrame(data)
temperature_df
# Out:
#                             _id         region  country    state        city  \
# 0      655d1f8276c65e6d96c48f90         Africa  Algeria              Algiers
# 1      655d1f8276c65e6d96c48f91         Africa  Algeria              Algiers
# 2      655d1f8276c65e6d96c48f92         Africa  Algeria              Algiers
# 3      655d1f8276c65e6d96c48f93         Africa  Algeria              Algiers
# 4      655d1f8276c65e6d96c48f94         Africa  Algeria              Algiers
# ...                         ...            ...      ...      ...         ...
# 24507  65746dfaf9d7d65e9eae8732  North America       US  Alabama  Birmingham
# 24508  65746dfaf9d7d65e9eae8733  North America       US  Alabama  Birmingham
# 24509  65746dfaf9d7d65e9eae8734  North America       US  Alabama  Birmingham
# 24510  65746dfaf9d7d65e9eae8735  North America       US  Alabama  Birmingham
# 24511  65746dfaf9d7d65e9eae8736  North America       US  Alabama  Birmingham
#
#        year  average_temperature
# 0      1997            64.926301
# 1      1998            63.619668
# 2      1999            64.923626
# 3      2000            64.182787
# 4      2001            64.669863
# ...     ...                  ...
# 24507  2016            58.316256
# 24508  2017            57.943395
# 24509  2018            57.039166
# 24510  2019            56.780607
# 24511  2020            47.399678
#
# [24512 rows x 7 columns]

# %%
temperature_df.drop(['_id', 'state','region', 'city'], axis=1, inplace=True)
temperature_df['average_temperature'] = temperature_df['average_temperature'].round(2)
temperature_df['country'] = temperature_df['country'].replace({'US': 'USA'})
temperature_df
# Out:
#        country  year  average_temperature
# 0      Algeria  1997                64.93
# 1      Algeria  1998                63.62
# 2      Algeria  1999                64.92
# 3      Algeria  2000                64.18
# 4      Algeria  2001                64.67
# ...        ...   ...                  ...
# 24507      USA  2016                58.32
# 24508      USA  2017                57.94
# 24509      USA  2018                57.04
# 24510      USA  2019                56.78
# 24511      USA  2020                47.40
#
# [24512 rows x 3 columns]

# %%
temperature_df.dtypes
# Out:
# country                 object
# year                     int64
# average_temperature    float64
# dtype: object

# %%
temperature_df = temperature_df.pivot_table(index='country', columns='year', values='average_temperature', aggfunc='mean')
# Resetting index to make 'Country or Area' a regular column 
temperature_df = temperature_df.reset_index()
# Remove column name for index (was affecting layout)
temperature_df.columns.name = None
temperature_df
# Out:
#         country   1995   1996   1997   1998   1999   2000   2001   2002  \
# 0       Albania    NaN    NaN  71.93  61.61  63.12  63.18  61.24  63.30
# 1       Algeria  64.41  63.53  64.93  63.62  64.92  64.18  64.67  64.14
# 2     Argentina  61.70  62.71  63.14  61.76  61.84  62.40  63.34  63.01
# 3     Australia  61.50  61.26  62.15  62.20  62.47  62.25  62.23  62.69
# 4       Austria  50.25  47.68  49.68  51.34  50.96  52.76  50.82  51.87
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
#
#          1995    1996    1997    1998    1999    2000    2001    2002    2003  \
# count  125.00  125.00  125.00  125.00  125.00  125.00  125.00  125.00  125.00
# mean    66.04   65.27   65.48   66.13   65.56   65.44   65.69   66.26   66.30
# std     13.36   14.07   13.93   13.73   13.22   12.95   13.30   13.30   13.48
# min     31.94   30.54   28.99   32.97   31.31   30.03   29.41   29.70   29.59
# 25%     54.39   54.14   52.60   53.76   53.66   53.83   53.38   53.83   54.46
# 50%     67.57   66.59   67.09   66.60   66.72   65.70   66.00   66.31   67.15
# 75%     78.36   78.77   78.83   79.52   78.52   78.89   79.28   79.65   79.86
# max     90.75   86.10   87.43   85.34   84.38   84.46   85.43   85.93   87.51
#
#          2004  ...    2011    2012    2013    2014    2015    2016    2017  \
# count  125.00  ...  125.00  125.00  125.00  125.00  125.00  125.00  125.00
# mean    66.07  ...   66.34   66.05   66.20   66.62   66.91   66.88   66.71
# std     13.55  ...   13.41   13.61   13.57   13.26   13.43   13.66   13.64
# min     31.49  ...   27.86   26.25   29.00   30.48   31.87   29.36   31.12
# 25%     54.22  ...   53.75   54.40   54.22   54.59   55.19   54.83   54.14
# 50%     66.75  ...   66.98   67.90   67.14   67.23   67.42   67.49   66.83
# 75%     79.43  ...   79.64   79.32   79.62   79.61   80.34   80.23   80.27
# max     86.29  ...   84.71   84.58   85.37   85.11   86.47   85.15   85.44
#
#          2018    2019    2020
# count  125.00  125.00  125.00
# mean    66.72   67.12   62.51
# std     13.28   13.43   16.92
# min     31.04   31.05   17.42
# 25%     54.53   55.58   46.37
# 50%     66.86   67.41   68.16
# 75%     79.54   80.15   79.23
# max     85.36   84.75   85.74
#
# [8 rows x 26 columns]

# %%
#Checking for outliers 

Q1 = temperature_df.quantile(0.25)
Q3 = temperature_df.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (temperature_df < lower_bound) | (temperature_df > upper_bound)

# Display outliers
outliers_countries = temperature_df[['country']][outliers.any(axis=1)]
outliers_countries
# Out:
# Empty DataFrame
# Columns: [country]
# Index: []

# %%
# Mean temperature levels for each country
mean_temperature = temperature_years.mean(axis=1)

mean_temperature_df = pd.DataFrame({'country': temperature_df['country'], 'Mean_temperature': mean_temperature})

# Sort by mean pollution levels in descending order
top_performers = mean_temperature_df.sort_values(by='Mean_temperature', ascending=False).round(2)

# Show top 10
top_performers.head(10)
# Out:
#                   country  Mean_temperature
# 44                  Haiti             85.25
# 78                Nigeria             84.15
# 50              Indonesia             83.45
# 117  United Arab Emirates             83.07
# 43                 Guyana             82.80
# 88                  Qatar             82.74
# 85            Philippines             82.40
# 67               Malaysia             82.36
# 42          Guinea-Bissau             82.35
# 108              Thailand             82.35

# %%
# Sort ascending order 
bottom_performers = mean_temperature_df.sort_values(by='Mean_temperature').round(2)
# Show bottom 10
bottom_performers.head(10)
# Out:
#       country  Mean_temperature
# 70   Mongolia             30.01
# 18     Canada             41.30
# 48    Iceland             41.37
# 80     Norway             41.62
# 33    Finland             42.52
# 90     Russia             44.67
# 9     Belarus             45.19
# 62     Latvia             45.22
# 102    Sweden             45.47
# 14    Bolivia             45.57

# %%
try:
    engine = create_engine('postgresql://dap:dap@192.168.56.30:5432/climate')

    temperature_df.to_sql('global_temperature', engine, index=False, if_exists='replace')

    print("DataFrame uploaded to PostgreSQL successfully.")

except Exception as e:
    print("Error:", e)
# Out:
# DataFrame uploaded to PostgreSQL successfully.
